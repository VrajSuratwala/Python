# %%
print("CSV WITH PANDAS")

import pandas as pd
# Out:
# CSV WITH PANDAS

# %%
data  = pd.read_csv('titanic.csv')
data.head(5)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
data.loc[0,"Name"]
# Out:
# 'Kelly, Mr. James'

# %%
data.loc[:,["Name","Age"]]
# Out:
#                                              Name   Age
# 0                                Kelly, Mr. James  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0
# 2                       Myles, Mr. Thomas Francis  62.0
# 3                                Wirz, Mr. Albert  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..                                            ...   ...
# 413                            Spector, Mr. Woolf   NaN
# 414                  Oliva y Ocana, Dona. Fermina  39.0
# 415                  Saether, Mr. Simon Sivertsen  38.5
# 416                           Ware, Mr. Frederick   NaN
# 417                      Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]

# %%
data.iloc[[0,5],[0,5]]
# Out:
#    PassengerId   Age
# 0          892  34.5
# 5          897  14.0

# %%
df = data.loc[data["Age"] == 50]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 25           917         0       3
# 30           922         0       2
# 218         1110         1       1
# 355         1247         0       1
# 407         1299         0       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 25                        Robins, Mr. Alexander A    male  50.0      1      0
# 30                   Louch, Mr. Charles Alexander    male  50.0      1      0
# 218  Widener, Mrs. George Dunton (Eleanor Elkins)  female  50.0      1      1
# 355                      Julian, Mr. Henry Forbes    male  50.0      0      0
# 407                    Widener, Mr. George Dunton    male  50.0      1      1
#
#          Ticket   Fare Cabin Embarked
# 25    A/5. 3337   14.5   NaN        S
# 30   SC/AH 3085   26.0   NaN        S
# 218      113503  211.5   C80        C
# 355      113044   26.0   E60        S
# 407      113503  211.5   C80        C

# %%
data.iloc[:5,:4]
# Out:
#    PassengerId  Survived  Pclass                                          Name
# 0          892         0       3                              Kelly, Mr. James
# 1          893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2          894         0       2                     Myles, Mr. Thomas Francis
# 3          895         0       3                              Wirz, Mr. Albert
# 4          896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data = pd.read_csv('titanic.csv',skiprows = 10)
data
# Out:
#       901  0  3                            Davies, Mr. John Samuel    male  \
# 0     902  0  3                                   Ilieff, Mr. Ylio    male
# 1     903  0  1                         Jones, Mr. Charles Cresson    male
# 2     904  1  1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 3     905  0  2                               Howard, Mr. Benjamin    male
# 4     906  1  1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female
# ..    ... .. ..                                                ...     ...
# 403  1305  0  3                                 Spector, Mr. Woolf    male
# 404  1306  1  1                       Oliva y Ocana, Dona. Fermina  female
# 405  1307  0  3                       Saether, Mr. Simon Sivertsen    male
# 406  1308  0  3                                Ware, Mr. Frederick    male
# 407  1309  0  3                           Peter, Master. Michael J    male
#
#        21  2  0.1           A/4 48871     24.15 Unnamed: 10  S
# ...

# %%
data = pd.read_csv('titanic.csv',nrows = 10)
data
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
data = pd.read_csv('titanic.csv',usecols = [2,4,6])
data
# Out:
#      Pclass     Sex  SibSp
# 0         3    male      0
# 1         3  female      1
# 2         2    male      0
# 3         3    male      0
# 4         3  female      1
# ..      ...     ...    ...
# 413       3    male      0
# 414       1  female      0
# 415       3    male      0
# 416       3    male      0
# 417       3    male      1
#
# [418 rows x 3 columns]

# %%
data.head(-2)
# Out:
#      Pclass     Sex  SibSp
# 0         3    male      0
# 1         3  female      1
# 2         2    male      0
# 3         3    male      0
# 4         3  female      1
# ..      ...     ...    ...
# 411       1  female      1
# 412       3  female      0
# 413       3    male      0
# 414       1  female      0
# 415       3    male      0
#
# [416 rows x 3 columns]

# %%
data.tail(-2)
# Out:
#      Pclass     Sex  SibSp
# 2         2    male      0
# 3         3    male      0
# 4         3  female      1
# 5         3    male      0
# 6         3  female      0
# ..      ...     ...    ...
# 413       3    male      0
# 414       1  female      0
# 415       3    male      0
# 416       3    male      0
# 417       3    male      1
#
# [416 rows x 3 columns]

# %%
df = pd.read_csv('titanic.csv')
df['Age'].unique()
# Out:
# array([34.5 , 47.  , 62.  , 27.  , 22.  , 14.  , 30.  , 26.  , 18.  ,
#        21.  ,   nan, 46.  , 23.  , 63.  , 24.  , 35.  , 45.  , 55.  ,
#         9.  , 48.  , 50.  , 22.5 , 41.  , 33.  , 18.5 , 25.  , 39.  ,
#        60.  , 36.  , 20.  , 28.  , 10.  , 17.  , 32.  , 13.  , 31.  ,
#        29.  , 28.5 , 32.5 ,  6.  , 67.  , 49.  ,  2.  , 76.  , 43.  ,
#        16.  ,  1.  , 12.  , 42.  , 53.  , 26.5 , 40.  , 61.  , 60.5 ,
#         7.  , 15.  , 54.  , 64.  , 37.  , 34.  , 11.5 ,  8.  ,  0.33,
#        38.  , 57.  , 40.5 ,  0.92, 19.  , 36.5 ,  0.75,  0.83, 58.  ,
#         0.17, 59.  , 14.5 , 44.  ,  5.  , 51.  ,  3.  , 38.5 ])

# %%
df['Age'].nunique()
# Out:
# 79

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (418, 12)

# %%
df.size
# Out:
# 5016

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %%
df['Age'].isna()

# isna() - return has N/A Value
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413     True
# 414    False
# 415    False
# 416     True
# 417     True
# Name: Age, Length: 418, dtype: bool

# %%
df['Age'].isna().sum()
# Out:
# 86

# %%
df['Age'].head(10)
# Out:
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# 5    14.0
# 6    30.0
# 7    26.0
# 8    18.0
# 9    21.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(20)
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413    20.0
# 414    39.0
# 415    38.5
# 416    20.0
# 417    20.0
# Name: Age, Length: 418, dtype: float64

# %%
df['Age'].mean()
# Out:
# 30.272590361445783

# %%
df['Age'].median()
# Out:
# 27.0

# %%
df['Age'].std()
# Out:
# 14.181209235624422

# %%
df.drop('Cabin',axis = 1 , inplace =True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.dropna(axis = 1 ,inplace = True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ..                                            ...     ...    ...    ...
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 408                  Riordan, Miss. Johanna Hannah""  female      0      0
# 409                        Peacock, Miss. Treasteall  female      1      1
# 410                           Naughton, Miss. Hannah  female      0      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female      1      0
# 412                   Henriksson, Miss. Jenny Lovisa  female      0      0
# 413                               Spector, Mr. Woolf    male      0      0
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
# df.loc[len(df)] = [417,	1309,	0,	3,	"Peter, Master. Michael J","male",	1,	1,	2668	,"C"]

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ..                                            ...     ...    ...    ...
# ...

# %%
df1=df[['SibSp','Parch']]

# %%
df1.cov()
# Out:
#           SibSp     Parch
# SibSp  0.804178  0.270100
# Parch  0.270100  0.963203

# %%
df1.corr()
# Out:
#           SibSp     Parch
# SibSp  1.000000  0.306895
# Parch  0.306895  1.000000
